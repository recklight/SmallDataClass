# %% [markdown]
# # Siamese Network做人臉識別
# ## **無大量資料可用**
# * over fitting(train太多次overfit小資料集)
# * under fitting(train很少次沒有gradient descent完全)
#
# ## Siamese:
# * 訓練目標: 比較是否同類
# * 意義: 增加訓練比數
#     * 以一家500人公司的人臉辨識為例，原本訓練目標為"在500類中找出一類"的話每類頂多有5張照片，這樣訓練資料遠遠不夠
#     * 但若是訓練目標為"分辨兩張照片是否相異"的話，相同的共有5000組、相異的共有3,118,750組，訓練資料爆炸性成長。
# * 結構: 用兩對稱神經網路(通常共享network+weight)將兩個input投射到同個特徵空間中，後續用彼此關係(稱為能量函數$E$)判斷異同
#     * 例如我們有兩個圖像$X_1$和$X_2$，進完兩個Network $f_1$和$f_2$ (其實兩個網路內容一樣)之後，以Eucledian Distnace為能量函數
#     * 輸出會是$E$($f_1(X_1)$,$f_2(X_2)$)
#     * 這個輸出若是接近0，則代表兩者類型相同，值很大代表兩者相差很多。

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# * 訓練方式: [contrastive loss](https://towardsdatascience.com/how-to-choose-your-loss-when-designing-a-siamese-neural-net-contrastive-triplet-or-quadruplet-ecba11944ec)-在特徵空間上，同類距離靠近，異類距離拉遠
#     * 答案為兩者相同時，套用loss為$distace$本身
#     * 答案為兩者不同十套用loss為$max(0,m-distance)^2$
#     * m為這個loss的最大值，這邊設為1
#     * 在兩者不同時，若是distance>1則不做訓練(已符合要求)，若distance<1，則開始使distance變大。

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * 使用方式: 需要將待測資料與每個class取一張以上做比對，比較花時間

# %% [markdown]
# ## 範例內容
# 這邊使用[AT & T's the Database of Faces](https://www.kaggle.com/kasikrit/att-database-of-faces)做人臉辨識範例，40個人每人共有10張不同角度的照片
#
# 例如subject 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Subject 13

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 接者會將照片兩兩一組不重複的分成"同個人"(Genuine)、"假扮者"(Imposite)，兩個class。
#
# 會將圖片以組為單位丟進Siamese Network中，並且以output為0("同個人")或1("假扮者")做label。

# %% [markdown]
# 程式碼部分會做以下部分：
# * Data Loader
# * 資料抽樣、切分
# * 建立模型
# * 模型訓練
# * 預測結果

# %% [markdown]
# # Data Loader
# * (meta)batch: 一次訓練BATCH_SIZE個task
# * task: 選2人不重複
# * sample: 2人資料中選一張當support，還要從剩下19張選一張query

# %%
# Colab上的話要下載資料
# !gdown https://drive.google.com/u/1/uc?id=1sSAsIVQl4u_eMWw4t9dfD3gGnHKwAUhz&export=download
# !unzip orl_faces.zip
# !mv orl_faces/ ..

# %%
'''Toolboxs'''
import cv2
import re
import os
from os.path import join
import numpy as np
from glob import glob
from tqdm import tqdm
import matplotlib.pyplot as plt
from functools import partial
from sklearn.model_selection import train_test_split
'''Tensorflow'''
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras import backend as K
from tensorflow.keras import callbacks as cb
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.layers import Input, Lambda, Dense, Dropout, \
                           Convolution2D, MaxPooling2D, Flatten,Activation

gpus = tf.config.experimental.list_physical_devices(device_type='GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth( device=gpu, enable=True)
if len(gpus)>1:
    os.environ["CUDA_VISIBLE_DEVICES"] = f"{len(gpus)-1}"

# %% [markdown]
# 先設定讀取圖片程式，這個資料集圖檔讀取方式需自訂，要輸入圖片的和寬、高、最大值，其中header是圖檔的標頭，讀取時要略過
#
# 圖片路徑為{orl_faces資料夾}/s1到s40
#
# 每個subject的圖片放在不同資料夾

# %%
W,H,CH = 64,64,1
'''pgm檔讀取程式'''
def read_pgm(filename):
    byteorder='>'
    #first we read the image, as a raw file to the buffer
    with open(filename, 'rb') as f:
        buffer = f.read()
    
    #using regex, we extract the header, width, height and maxval of the image
    header, width, height, maxval = re.search(
        b"(^P5\s(?:\s*#.*[\r\n])*"
        b"(\d+)\s(?:\s*#.*[\r\n])*"
        b"(\d+)\s(?:\s*#.*[\r\n])*"
        b"(\d+)\s(?:\s*#.*[\r\n]\s)*)", buffer).groups()
    
    #then we convert the image to numpy array using np.frombuffer which interprets buffer as one dimensional array
    return np.frombuffer(buffer,
                            dtype='u1' if int(maxval) < 256 else byteorder+'u2',
                            count=int(width)*int(height),
                            offset=len(header)
                            ).reshape((int(height), int(width)))
'''完整影像讀取程式，含pre-process'''
def load_img(path, width = W):
    '''讀出來並從0~255縮到0~1間'''
    img = read_pgm(path.numpy().decode()).astype(np.float32)/255.
    '''依照比較短的邊為指定長度，長的那邊只剪下中間指定長度的距離'''
    shape_dst = np.min(img.shape[:2])
    oh = (img.shape[0] - shape_dst) // 2
    ow = (img.shape[1] - shape_dst) // 2
    center_square = np.array([width,width])// 2
    new_size=(width,width)
    
    '''Cropping + resize'''
    img = img[oh:oh + shape_dst, ow:ow + shape_dst]
    img=np.expand_dims(cv2.resize(img, new_size),-1) # for tensorflow cnn
    return tf.constant(img)
SUFFIX='.pgm'

# %% [markdown]
# 先設好要使用的參數

# %%
WAYS = 2
QUERIES=1
BATCH_SIZE=64

# %% [markdown]
# 首先列出sourse跟target有哪些classes

# %%
np.random.seed(2021)
tf.random.set_seed(2021)
DATA_ROOT=".."
# DATA_ROOT=join("..","..","data")
# DATA_ROOT="I:\AIA Small Data\datasets"
all_classes = glob(join(DATA_ROOT,"orl_faces","*"))
source_classes,target_classes=train_test_split(all_classes,test_size=0.2)
sorce_len=len(source_classes)
target_len=len(target_classes)
print(f"total {len(all_classes)} classes=source {sorce_len} + target {target_len} classes")
# Out:
# total 40 classes=source 32 + target 8 classes

# %% [markdown]
# 確認各個class中至少有幾張，沒有個兩張是不行的，因為就不能比了

# %%
min([len(glob(join(sdir,'*'+SUFFIX))) for sdir in source_classes])
# Out:
# 10

# %% [markdown]
# 建立每個人的資料loader

# %%
'''Mapping function for loading'''
map_fun=lambda string: tf.py_function(func=load_img,inp=[string], Tout=tf.float32)
'''Source set中每個人都有一個tf Dataset loader'''
source_sup_sub = [
    tf.data.Dataset.list_files(glob(join(sc,'*'+SUFFIX)), shuffle=True)
    .map(map_fun).cache()
    for sc in source_classes
]
source_q_sub = [
    tf.data.Dataset.list_files(glob(join(sc,'*'+SUFFIX)), shuffle=True)
    .map(map_fun).cache()
    for sc in source_classes
]
'''Target set中每個人都有一個tf Dataset loader'''
target_sup_sub = [
    tf.data.Dataset.list_files(glob(join(sc,'*'+SUFFIX)), shuffle=True)
    .map(map_fun).cache()
    for sc in target_classes
]
target_q_sub = [
    tf.data.Dataset.list_files(glob(join(sc,'*'+SUFFIX)), shuffle=True)
    .map(map_fun).cache()
    for sc in target_classes
]

# %% [markdown]
# **將所有可能run過一遍，讓cache記得**

# %%
# %%time
for sub in source_sup_sub :
    for x in iter(sub.batch(10)):
        pass
for sub in source_q_sub :
    for x in iter(sub.batch(10)):
        pass
# Out:
# CPU times: user 731 ms, sys: 670 ms, total: 1.4 s
# Wall time: 1.38 s

# %%
# %%time
for sub in target_sup_sub :
    for x in iter(sub.batch(10)):
        pass
for sub in target_q_sub :
    for x in iter(sub.batch(10)):
        pass
# Out:
# CPU times: user 180 ms, sys: 169 ms, total: 349 ms
# Wall time: 335 ms

# %% [markdown]
# 下一步，組成Data loader

# %%
def gen(sup_sub,query_sub):
    '''將順序打亂排列成數組pair'''
    order=np.random.permutation(len(sup_sub))
    for task in range(len(sup_sub)//WAYS):
        '''兩兩一組'''
        picked_s=[sup_sub[tt] for tt in order[WAYS*task:WAYS*(task+1)]]
        picked_q=[query_sub[tt] for tt in order[WAYS*task:WAYS*(task+1)]]
        '''選一個人當 support'''
        idx_s=np.random.choice(range(WAYS), size=1, replace=False)
        '''support挑一張照片'''
        support = [next(iter(
                        picked_s[idx].batch(1).prefetch(1)
                    )) for idx in idx_s]
        
        '''選QUERIES張照片當 query'''
        idx_q=np.random.choice(range(WAYS), size=QUERIES, replace=False)
        query = [next(iter(
                        picked_q[idx].batch(1).prefetch(1)
                    )) for idx in idx_q]
        '''Support跟query照片合併起來當x'''
        x=tf.concat(support+query, axis=0)
        '''如果該query照片跟support同種就是1，不同就是0'''
        y=tf.concat([tf.constant(idx_s==idx,dtype=tf.float32) for idx in idx_q],axis=0)
        yield x, y

# %% [markdown]
# 建立data generator，可以一次抽一個meta batch的資料
# 1. 要input一個function(這邊用partial產生一個預先設定好參數的function)
# 1. output types要對好前面的格式
# 2. output shape要給對

# %%
MLUT=40
data_source = tf.data.Dataset.from_generator(partial(gen,source_sup_sub,source_q_sub),
                                    output_types=(tf.float32,tf.float32),
                                    output_shapes=((2,W,H,CH),QUERIES)).repeat(MLUT).shuffle(buffer_size=999).cache().batch(BATCH_SIZE).prefetch(MLUT)
data_target = tf.data.Dataset.from_generator(partial(gen,target_sup_sub,target_q_sub),
                                    output_types=(tf.float32,tf.float32),
                                    output_shapes=((2,W,H,CH),QUERIES)).repeat(MLUT).batch(BATCH_SIZE).prefetch(MLUT)

# %% [markdown]
# 可以看一下每次sample出來的東西
# * X:共BATCH_SIZE個meta batch,每個metabatch有1+QUERIES個圖，每個圖WxHxCH大小
# * y:每個meta batch共QUERIES個答案，顯示兩張照片是否相同人

# %%
for source_x,source_y in data_source:
    break

# %%
print(source_x.shape,source_y.shape)
# Out:
# (64, 2, 64, 64, 1) (64, 1)

# %%
NUMS=4
plt.figure(figsize=(5,NUMS+2));
ii=1
for sample_x,sample_y in zip(source_x[:NUMS],source_y[:NUMS]):
    for takes in sample_x:
        plt.subplot(NUMS,WAYS,ii);plt.imshow(takes[...,0],"gray");plt.axis("off")
        
        ii+=1
    rslt="Same" if sample_y[0] else "Different"
    plt.title(rslt)

# %% [markdown]
# # 建立模型
# Base model的話範例使用兩層Convolution做為主要network，選ReLu activation且每層中有max pooling和drop out。output前使用兩層MLP化為一個50維向量。

# %%
def build_base_network(input_shape):
    seq = Sequential()
    
    nb_filter = [128,128]
    kernel_size = 3
    #convolutional layer 1
    seq.add(Convolution2D(nb_filter[0], kernel_size, kernel_size, input_shape=input_shape,
                           padding="valid",activation='relu'))
    seq.add(MaxPooling2D(pool_size=(2, 2)))  
    seq.add(Dropout(.25))
    
    #convolutional layer 2
    seq.add(Convolution2D(nb_filter[1], kernel_size, kernel_size, padding="valid",activation='relu'))
    seq.add(MaxPooling2D(pool_size=(2, 2))) 
    seq.add(Dropout(.25))

    #flatten 
    seq.add(Flatten())
    seq.add(Dense(128, activation='relu'))
    seq.add(Dropout(0.1))
    seq.add(Dense(50, activation='relu'))
    return seq

'''計算latent距離'''
def euclidean_distance(vects):
    x, y = vects
    return K.sqrt(K.sum(K.square(x - y), axis=1, keepdims=True))
'''給Lambda layer用的'''
def eucl_dist_output_shape(shapes):
    shape1, shape2 = shapes
    return (shape1[0], 1)
'''計算距離，可自訂prediction是要多小才算兩者同類'''
def accu(labels,predictions):
    return K.mean((labels==1)==(predictions<0.5))

# %% [markdown]
# 接著引導兩個不同影像分別輸進base_network，輸出feat_vecs_a、feat_vecs_b再計算euclidean distance。
# Model 使用RMSprop做 optimization。

# %%
'''比一般Model input要多一個rank, 區分一次要比較的每一張照片'''
input_dim = (1+QUERIES,W,H,CH)
imgs = Input(shape=input_dim)
base_network = build_base_network(input_dim[1:])

'''算好support latent'''
support_vec=base_network(imgs[:,0,...])
pred=[]
for qq in range(QUERIES):
    '''算query latent'''
    query_vec=base_network(imgs[:,1+qq,...])
    '''算距離'''
    pred.append(Lambda(euclidean_distance, output_shape=eucl_dist_output_shape)([support_vec,query_vec]))
distance=tf.concat(pred,axis=-1)

model = Model(inputs=imgs, outputs=distance)

# %% [markdown]
# # 模型訓練
# 訓練使用10 epoch、batch size為16個pairs，並指定loss function為contrastive_loss。
# 在訓練時再使用validation split驗證loss是否下降，或者只是over fitting。

# %%
lr=0.001
'''同類的時候套用左邊的式子，不同類時套用右邊的式子'''
def contrastive_loss(isgenuine, y_pred):
    margin = 1
    return K.mean(isgenuine * K.square(y_pred) + (1 - isgenuine) * K.square(K.maximum(margin - y_pred, 0)))
'''套用RMSProp optimizer，要的話也可以試Adam'''
rms = RMSprop(learning_rate=lr)

model.compile(loss=contrastive_loss, optimizer=rms,metrics=[accu])

# %%
EPOCHS=400
'''開一些callbacks紀錄、調整lr、自動結束訓練'''
reduce_lr = cb.ReduceLROnPlateau(monitor='val_loss', factor=0.1,patience=5, min_lr=1e-8, verbose=1)
tensorboard = cb.TensorBoard(log_dir="tf_siamese_logs")
earlystop=cb.EarlyStopping(monitor='val_loss',patience=10,restore_best_weights=True, verbose=1)

# %%time
try:
    '''用同個generator來validate也還好，因為每次都是不同task'''
    model.fit(data_source, epochs=EPOCHS, verbose=1,workers=4,callbacks=[reduce_lr,earlystop, tensorboard], validation_data=data_source)
except KeyboardInterrupt:
    print("KeyboardInterrupt")
# Out:
# Epoch 1/400
#       2/Unknown - 0s 58ms/step - loss: 0.2783 - accu: 0.5703 WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0067s vs `on_train_batch_end` time: 0.1088s). Check your callbacks.
# 10/10 [==============================] - 0s 40ms/step - loss: 0.2613 - accu: 0.5391 - val_loss: 0.4163 - val_accu: 0.4703
# Epoch 2/400
# 10/10 [==============================] - 0s 10ms/step - loss: 0.2547 - accu: 0.5281 - val_loss: 0.3990 - val_accu: 0.4703
# Epoch 3/400
# 10/10 [==============================] - 0s 10ms/step - loss: 0.2600 - accu: 0.5281 - val_loss: 0.3860 - val_accu: 0.4703
# Epoch 4/400
# 10/10 [==============================] - 0s 10ms/step - loss: 0.2458 - accu: 0.5547 - val_loss: 0.3526 - val_accu: 0.4797
# Epoch 5/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2452 - accu: 0.5781 - val_loss: 0.3320 - val_accu: 0.4969
# Epoch 6/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2262 - accu: 0.6391 - val_loss: 0.2714 - val_accu: 0.6156
# Epoch 7/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2244 - accu: 0.6281 - val_loss: 0.2489 - val_accu: 0.6656
# Epoch 8/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.2211 - accu: 0.6250 - val_loss: 0.2203 - val_accu: 0.6969
# Epoch 9/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1983 - accu: 0.6703 - val_loss: 0.1913 - val_accu: 0.7281
# Epoch 10/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1889 - accu: 0.7141 - val_loss: 0.1717 - val_accu: 0.7594
# Epoch 11/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1746 - accu: 0.7344 - val_loss: 0.1620 - val_accu: 0.7688
# Epoch 12/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1668 - accu: 0.7422 - val_loss: 0.1497 - val_accu: 0.7922
# Epoch 13/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1655 - accu: 0.7281 - val_loss: 0.1515 - val_accu: 0.7891
# Epoch 14/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1589 - accu: 0.7688 - val_loss: 0.1302 - val_accu: 0.8234
# Epoch 15/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1599 - accu: 0.7812 - val_loss: 0.1226 - val_accu: 0.8328
# Epoch 16/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1533 - accu: 0.7719 - val_loss: 0.1311 - val_accu: 0.8125
# Epoch 17/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1442 - accu: 0.7937 - val_loss: 0.1321 - val_accu: 0.8234
# Epoch 18/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1401 - accu: 0.8062 - val_loss: 0.1343 - val_accu: 0.8234
# Epoch 19/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1373 - accu: 0.7937 - val_loss: 0.1099 - val_accu: 0.8406
# Epoch 20/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1387 - accu: 0.7937 - val_loss: 0.1069 - val_accu: 0.8531
# Epoch 21/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1261 - accu: 0.8266 - val_loss: 0.0961 - val_accu: 0.8672
# Epoch 22/400
# 10/10 [==============================] - 0s 10ms/step - loss: 0.1351 - accu: 0.8172 - val_loss: 0.0949 - val_accu: 0.8703
# Epoch 23/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1301 - accu: 0.8172 - val_loss: 0.0977 - val_accu: 0.8625
# Epoch 24/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1195 - accu: 0.8406 - val_loss: 0.0907 - val_accu: 0.8734
# Epoch 25/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1337 - accu: 0.8094 - val_loss: 0.0935 - val_accu: 0.8656
# Epoch 26/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1222 - accu: 0.8328 - val_loss: 0.0927 - val_accu: 0.8656
# Epoch 27/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1243 - accu: 0.8156 - val_loss: 0.0850 - val_accu: 0.8797
# Epoch 28/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1164 - accu: 0.8531 - val_loss: 0.0818 - val_accu: 0.8891
# Epoch 29/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1156 - accu: 0.8422 - val_loss: 0.0785 - val_accu: 0.8813
# Epoch 30/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1068 - accu: 0.8625 - val_loss: 0.0806 - val_accu: 0.8844
# Epoch 31/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1121 - accu: 0.8578 - val_loss: 0.0647 - val_accu: 0.9187
# Epoch 32/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1200 - accu: 0.8219 - val_loss: 0.0732 - val_accu: 0.8984
# Epoch 33/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1047 - accu: 0.8641 - val_loss: 0.0614 - val_accu: 0.9172
# Epoch 34/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1089 - accu: 0.8453 - val_loss: 0.0726 - val_accu: 0.8969
# Epoch 35/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1084 - accu: 0.8438 - val_loss: 0.0683 - val_accu: 0.9062
# Epoch 36/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0994 - accu: 0.8734 - val_loss: 0.0887 - val_accu: 0.8859
# Epoch 37/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1000 - accu: 0.8625 - val_loss: 0.0793 - val_accu: 0.8891
# Epoch 38/400
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0822 - accu: 0.9062
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0987 - accu: 0.8813 - val_loss: 0.0725 - val_accu: 0.8953
# Epoch 39/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0892 - accu: 0.8859 - val_loss: 0.0606 - val_accu: 0.9219
# Epoch 40/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0918 - accu: 0.8906 - val_loss: 0.0587 - val_accu: 0.9266
# Epoch 41/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0835 - accu: 0.9047 - val_loss: 0.0568 - val_accu: 0.9328
# Epoch 42/400
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0834 - accu: 0.8969 - val_loss: 0.0549 - val_accu: 0.9344
# Epoch 43/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0848 - accu: 0.9016 - val_loss: 0.0545 - val_accu: 0.9312
# Epoch 44/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0884 - accu: 0.8938 - val_loss: 0.0542 - val_accu: 0.9391
# Epoch 45/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0866 - accu: 0.8938 - val_loss: 0.0551 - val_accu: 0.9359
# Epoch 46/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0860 - accu: 0.8938 - val_loss: 0.0541 - val_accu: 0.9375
# Epoch 47/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0809 - accu: 0.9094 - val_loss: 0.0543 - val_accu: 0.9359
# Epoch 48/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0855 - accu: 0.8953 - val_loss: 0.0528 - val_accu: 0.9359
# Epoch 49/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0826 - accu: 0.8938 - val_loss: 0.0501 - val_accu: 0.9375
# Epoch 50/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0866 - accu: 0.8984 - val_loss: 0.0518 - val_accu: 0.9344
# Epoch 51/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0865 - accu: 0.8922 - val_loss: 0.0531 - val_accu: 0.9375
# Epoch 52/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0799 - accu: 0.9062 - val_loss: 0.0530 - val_accu: 0.9344
# Epoch 53/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0841 - accu: 0.9047 - val_loss: 0.0522 - val_accu: 0.9359
# Epoch 54/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0771 - accu: 0.9203 - val_loss: 0.0496 - val_accu: 0.9391
# Epoch 55/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0736 - accu: 0.9094 - val_loss: 0.0489 - val_accu: 0.9422
# Epoch 56/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0801 - accu: 0.9172 - val_loss: 0.0488 - val_accu: 0.9438
# Epoch 57/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0814 - accu: 0.8969 - val_loss: 0.0499 - val_accu: 0.9359
# Epoch 58/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0819 - accu: 0.9094 - val_loss: 0.0501 - val_accu: 0.9375
# Epoch 59/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0808 - accu: 0.9094 - val_loss: 0.0498 - val_accu: 0.9406
# Epoch 60/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0824 - accu: 0.9031 - val_loss: 0.0505 - val_accu: 0.9375
# Epoch 61/400
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0615 - accu: 0.9375
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0833 - accu: 0.9078 - val_loss: 0.0504 - val_accu: 0.9406
# Epoch 62/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0806 - accu: 0.9031 - val_loss: 0.0500 - val_accu: 0.9406
# Epoch 63/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0841 - accu: 0.8984 - val_loss: 0.0496 - val_accu: 0.9391
# Epoch 64/400
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0779 - accu: 0.9078 - val_loss: 0.0495 - val_accu: 0.9391
# Epoch 65/400
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0775 - accu: 0.9094 - val_loss: 0.0494 - val_accu: 0.9375
# Epoch 66/400
#  1/10 [==>...........................] - ETA: 0s - loss: 0.0476 - accu: 0.9688
# Epoch 00066: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# Restoring model weights from the end of the best epoch.
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0727 - accu: 0.9250 - val_loss: 0.0494 - val_accu: 0.9391
# Epoch 00066: early stopping

# %% [markdown]
# # 預測結果
# 最後使用test data看accuracy，為distance取一個區間(e.g. 0.1)做為評判是否為同個類別的依據。

# %%
model.evaluate(data_target)
# Out:
# 3/3 [==============================] - 1s 386ms/step - loss: 0.1729 - accu: 0.7760
# [0.17292779684066772, 0.7760416865348816]

# %% [markdown]
# distance有可能>1

# %% [markdown]
# # Exercise
# 請各位使用Siamese訓練比較Omniglot資料集的兩個字是否相同:
#
# Omniglot資料集：
# * source有3856個來自不同語言的不同字符，target有659個不同字符
# * 每個class有20張不同人手寫的同一個文字的圖片
# * 每個task的support是隨機抽1張照片
# * query另外1張照片，需推論這張照片與support是否是相同種類字符(e.g. 都是 "人" 這個字)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **以下附上圖案讀取的code**
#
# 請自行撰寫data loader以及training內容
#
# e.g.
# ```
# # Data loader
# def gen(...):
#     ...
#     return X,y
#
# # 建立模型
# ...
# model = Model(inputs=imgs, outputs=distance)
#
# # 模型訓練
# ...
# model.fit(data_source,...,validation_data=data_source)
# ```

# %%
import numpy as np
import cv2

W,H,CH = 64,64,1

def read_image(path, width = W, hight=H):
    img=cv2.imread(path.numpy().decode())[...,0].astype(np.float32)/255.
#     img = read_pgm(path.numpy().decode()).astype(np.float32)/255.
    min_of_shape = np.min(img.shape[:2])
    oh = (img.shape[0] - min_of_shape) // 2
    ow = (img.shape[1] - min_of_shape) // 2
    center_square = np.array([width,hight])// 2
    new_size=(width,hight)
    
    # cropping + resize
    img = img[oh:oh + min_of_shape, ow:ow + min_of_shape]
    img=np.expand_dims(cv2.resize(img, new_size),-1)
    return tf.constant(img-0.5)
SUFFIX='.png'

# %% [markdown]
# # References
# [github](https://github.com/shruti-jadon/Hands-on-One-Shot-Learning)
#
# [Paper](https://proceedings.neurips.cc/paper/1993/file/288cc0ff022877bd3df94bc9360b9c5d-Paper.pdf)
